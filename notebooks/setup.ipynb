# %%
# ===============================================
# BASIC SETUP: GIT Auth and mounting google drive
# ================================================

from google.colab import drive, userdata
import sys

# Standard mount to access the config file initially
drive.mount('/content/drive')
sys.path.append(userdata.get('BIG_DATA_PATH'))

from utils.config import initialize_project
initialize_project()
# Out:
# Mounted at /content/drive
# Authenticated as: Spencer Novaco
# Working Directory: /content/drive/MyDrive/Sprint 2026/CIS 5570/Big-data-group-1/Room-Occupancy-Detection/src
